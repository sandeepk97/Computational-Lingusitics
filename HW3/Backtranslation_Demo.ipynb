# %% [markdown]
# # Install prerequisites for downloading pre-trained machine translation models

# %%
# !pip install transformers sentencepiece fasttext sacremoses

# %%
import pandas as pd
import tarfile
import gzip
from transformers import MarianMTModel, MarianTokenizer

# %% [markdown]
# # The Tatoeba Challenge Dataset

# %%
# !wget https://object.pouta.csc.fi/Tatoeba-Challenge-devtest/test.tar

tar = tarfile.open('/content/test.tar')
tar.extractall()
# Out:
# --2023-04-22 14:59:06--  https://object.pouta.csc.fi/Tatoeba-Challenge-devtest/test.tar
# Resolving object.pouta.csc.fi (object.pouta.csc.fi)... 86.50.254.18
# Connecting to object.pouta.csc.fi (object.pouta.csc.fi)|86.50.254.18|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 164843520 (157M) [application/x-tar]
# Saving to: ‘test.tar.1’
#
# test.tar.1          100%[===================>] 157.21M  21.5MB/s    in 8.2s
#
# 2023-04-22 14:59:15 (19.3 MB/s) - ‘test.tar.1’ saved [164843520/164843520]

# %%
source_target_path = '/content/data/release/test/v2021-08-07/tatoeba-test-v2021-08-07.eng-fra.txt.gz'
unzipped = gzip.GzipFile(source_target_path)
out = unzipped.read()
parallel = [x.split("\t") for x in out.decode("utf-8").split("\n")[0:-1]]
parallel[-1]
# Out:
# ['eng',
#  'fra',
#  '"Zugzwang" is a German word which, with reference to chess, means more or less the following: "obligation to make a move and, consequently, to lose the game".',
#  '« Zugzwang » est un mot allemand qui, en référence aux échecs, signifie plus ou moins ce qui suit : « Obligation de faire un mouvement et, par conséquent, de perdre la partie. »']

# %% [markdown]
# # Load in the models for translation into the target language and back from the target into the source language

# %%
model_name = "Helsinki-NLP/opus-mt-tc-big-en-fr"
tokenizer = MarianTokenizer.from_pretrained(model_name)
model = MarianMTModel.from_pretrained(model_name)

backmodel_name = "Helsinki-NLP/opus-mt-tc-big-fr-en"
backtokenizer = MarianTokenizer.from_pretrained(backmodel_name)
backmodel = MarianMTModel.from_pretrained(backmodel_name)
# Out:
# Downloading source.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# Downloading target.spm:   0%|          | 0.00/820k [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.33M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/337 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.14k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/570M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/301 [00:00<?, ?B/s]
# Downloading source.spm:   0%|          | 0.00/820k [00:00<?, ?B/s]
# Downloading target.spm:   0%|          | 0.00/802k [00:00<?, ?B/s]
# Downloading (…)olve/main/vocab.json:   0%|          | 0.00/1.33M [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/337 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/65.0 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/1.14k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/570M [00:00<?, ?B/s]
# Downloading (…)neration_config.json:   0%|          | 0.00/301 [00:00<?, ?B/s]

# %%
src_text = []
for i, (l1, _, sent, _) in enumerate(parallel):
  if l1=='eng':
    src_text.append((i, sent))
other_language = [parallel[i][-1] for i, sent in src_text]

# %%
df = pd.DataFrame(src_text, columns=['index', 'source'])
df['target'] = other_language

# %%
df.head()
# Out:
#    index                                             source  \
# 0      0  80% of all English words come from other langu...
# 1      1                  95 years old! God Save the Queen!
# 2      2                             Aah. Now I understand.
# 3      3                    A bad habit is easily acquired.
# 4      4  A better world for women is a better world for...
#
#                                               target
# 0  Quatre-vingt pour cent des mots anglais provie...
# 1                     95 ans ! Dieu sauve la reine !
# 2                     Ah ! Maintenant, je comprends.
# 3   Il est facile de prendre de mauvaises habitudes.
# 4  Un monde meilleur pour les femmes est un monde...

# %% [markdown]
# Sample from the original dataset because doing 10k sentences would take approximately a million years

# %%
sample_df = df.sample(n=120, replace=False)
sample_df.head()
# Out:
#        index                                             source  \
# 2180    2180  He criticized the war after leaving the military.
# 6891    6891                         Mary is a physics student.
# 774      774                                 Christmas is soon.
# 4357    4357                        I knew it was time to stop.
# 10098  10098  Tom didn't seem to be aware that he was suppos...
#
#                                                   target
# 2180   Il critiqua la guerre après avoir quitté les a...
# 6891                    Marie est étudiante en physique.
# 774                                 Noël arrive bientôt.
# 4357              Je savais qu'il était temps d'arrêter.
# 10098  Tom ne semblait pas au courant qu'il était cen...

# %% [markdown]
# Translate into target; translate back from target to source

# %%
outputs = []
for i, row in sample_df.iterrows():
  sent = row['source']
  # tokenize the source
  tokenized = tokenizer(sent, return_tensors="pt", padding=False)
  # generate the target language
  t = model.generate(**tokenized, max_new_tokens=len(tokenized['input_ids'][0]) + 3)[0]
  # produce a string of the target language
  out = tokenizer.decode(t, skip_special_tokens=True)
  print(row['target'], out)
  # take that string and translate it back into the source
  backtokenized = backtokenizer(out, return_tensors="pt", padding=True)
  backtranslated = backmodel.generate(
      **backtokenized, max_new_tokens=len(backtokenized['input_ids'][0] + 3))[0]
  # render backtranslation as a string
  backtranslated_string = backtokenizer.decode(backtranslated, skip_special_tokens=True)
  outputs.append((sent, backtranslated_string))
# Out:
# Il critiqua la guerre après avoir quitté les armes. Il a critiqué la guerre après avoir quitté l'armée.
# Marie est étudiante en physique. Mary est étudiante en physique.
# Noël arrive bientôt. Noël est bientôt.
# Je savais qu'il était temps d'arrêter. Je savais qu'il était temps d'arrêter.
# Tom ne semblait pas au courant qu'il était censé le faire. Tom n'avait pas l'air d'être au courant qu'il était censé faire
# Le robot fait tout ce que son maître lui ordonne. Le robot fait ce que son maître lui dit de faire.
# Pour perdre du poids, certaines personnes sautent les repas. Pour perdre du poids, certaines personnes sautent des repas.
# Essaie-la encore une fois. Essaie encore une fois.
# Je ne vais pas vous aider. Je ne vais pas t'aider.
# Quel est ton restaurant de restauration rapide préféré? Quel est votre fast-food préféré?
# Je t'ai vue avec lui. Je t'ai vu avec lui.
# Cette phrase est écrite en allemand. Cette phrase est écrite en allemand.
# Pourquoi ne me dis-tu pas que je suis belle ? Pourquoi ne m'as-tu pas dit que j'étais belle?
# Il n'est pas trop tard. Il n'est pas trop tard.
# C'est une tocade. C'est une mode.
# Qu'est-ce que vos enfants mangent d'habitude au petit-déjeuner ? Qu’est-ce que vos enfants mangent habituellement au petit
# Je viens de Krasnoyarsk. Je suis de Krasnoyarsk.
# C'est quelque chose de nouveau. C'est quelque chose de nouveau.
# Je suppose que tu as raison. Je suppose que vous avez raison.
# Cet homme-là est votre esclave, non ? Cette personne est votre esclave, n'est-ce
# Je ne te connais plus. Je ne te connais plus.
# Ne joue pas les héros ! N'essayez pas d'être un héros.
# J'allais lui demander de sortir avec moi, mais au dernier moment, mon courage a vacillé. J'allais lui demander de sortir, mais au dernier moment mon courage a faibli.
# Quand la réunion s'est-elle terminée ? Quand la réunion s'est-elle terminée
# Tu as l'air un peu remuée. Tu as l'air un peu secoué.
# C'est peut-être le 1er avril, mais votre farce a dépassé les bornes. Sérieusement, je suis très en colère ! Aujourd'hui, c'est peut-être le poisson d'avril, mais votre blague est passée par-dessus bord.
# Est-ce la clé que tu cherchais ? Est-ce la clé que vous recherchiez?
# Elle me fit un clin d'œil. Elle m'a fait un clin d'
# Elle lui annonça que son père était décédé. Elle lui a dit que son père était mort.
# Je suis très content. Je suis très heureux.
# Est-ce qu'on t'a déjà diagnostiqué un problème cardiaque ? Avez-vous déjà été diagnostiqué avec une maladie cardiaque?
# Le langage est l'outil par lequel les gens communiquent avec les autres. La langue est le moyen par lequel les gens communiquent avec les autres.
# C'est une blonde. C'est une blonde idiote.
# Ce problème est-il du type asservissement ou régulation ? S'agit-il d'un problème de servo ou de rejet des perturbations
# Nous avons un Président. Nous avons un président.
# J'ai entendu dire qu'en Angleterre l'herbe était verte même en hiver. On dit que l'herbe est verte même en hiver en Angleterre.
# La chambre est trop petite. La chambre est trop petite.
# Tom boit. Tom boit.
# Paul aime le chocolat. Paul aime le chocolat.
# Vous êtes dans une propriété privée, ici. Tu t'enfuis ici.
# En quoi seras-tu réincarnée ? Comment vous réincarnerez-vous?

# %% [markdown]
# # Inspect the output

# %%
out_df = pd.DataFrame(outputs, columns=['gold', 'backtranslated'])

# %%
out_df.head(30)
# Out:
#                                                  gold  \
# 0   He criticized the war after leaving the military.
# 1                          Mary is a physics student.
# 2                                  Christmas is soon.
# 3                         I knew it was time to stop.
# 4   Tom didn't seem to be aware that he was suppos...
# 5   The robot does whatever its master tells it to...
# 6     In order to lose weight some people skip meals.
# 7                                  Try it once again.
# 8                          I'm not going to help you.
# 9        What is your favourite fast-food restaurant?
# 10                                I saw you with him.
# 11                This sentence is written in German.
# 12             Why haven't you told me I'm beautiful?
# 13                                 It's not too late.
# 14                                        It's a fad.
# 15   What do your children usually eat for breakfast?
# 16                              I'm from Krasnoyarsk.
# 17                             This is something new.
# 18                           I suppose you are right.
# 19                  This person is your slave, right?
# 20                          I don't know you anymore.
# 21                            Don't try to be a hero.
# 22  I was going to ask her out, but at the last mo...
# 23                          When did the meeting end?
# 24                          You look a little shaken.
# 25  Today may be April Fool's Day, but your prank ...
# 26              Is this the key you were looking for?
# 27                                  She winked at me.
# 28  I think we've met before, but if I don't ring ...
# 29  None of our other problems are going to matter...
#
#                                        backtranslated
# 0       He criticized the war after leaving the army.
# 1                          Mary is a physics student.
# 2                            Christmas is coming soon
# 3                         I knew it was time to stop.
# 4   Tom didn't seem to know what he was supposed t...
# 5      The robot does what its master tells it to do.
# 6             To lose weight, some people skip meals.
# 7                                       Try it again.
# 8                             I'm not gonna help you.
# 9                    What is your favorite fast food?
# 10                                I saw you with him.
# 11                This sentence is written in German.
# 12            Why didn't you tell me I was beautiful?
# 13                                 It's not too late.
# 14                                         It's a fad
# 15                         What your kids usually eat
# 16                               I'm from Krasnoyarsk
# 17                                It's something new.
# 18                              I guess you're right.
# 19               This person is your slave, isn't he?
# 20                                   I don't know you
# 21                            Don't try to be a hero.
# 22  I was going to ask him out, but at the last mo...
# 23                          When did the meeting end?
# 24                          You look a little shaken.
# 25  Today may be April Fool's Day, but your joke h...
# 26              Is that the key you were looking for?
# 27                                 She gave me a wink
# 28  I think we've met before, but if I don't ring,...
# 29  None of our other problems will matter if the ...
